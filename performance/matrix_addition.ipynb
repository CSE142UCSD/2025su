# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# # Performance
#
# ## How programmers affects performance?

# %%
compare([do_render_code("./programmer/madd_A.c", lang="c++", show="main"),
do_render_code("./programmer/madd_B.c", lang="c++", show="main")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// ./programmer/madd_A.c:7-50 (44 lines)</span>
# <span class="kt">int</span><span class="w"> </span><span class="nf">main</span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="n">argc</span><span class="p">,</span><span class="w"> </span><span class="kt">char</span><span class="w"> </span><span class="o">**</span><span class="n">argv</span><span class="p">)</span>
# <span class="p">{</span>
# <span class="w">  </span><span class="kt">int</span><span class="w"> </span><span class="o">**</span><span class="n">a</span><span class="p">,</span><span class="w"> </span><span class="o">**</span><span class="n">b</span><span class="p">,</span><span class="w"> </span><span class="o">**</span><span class="n">c</span><span class="p">,</span><span class="w"> </span><span class="n">i</span><span class="p">,</span><span class="w"> </span><span class="n">j</span><span class="p">,</span><span class="w"> </span><span class="n">k</span><span class="p">;</span>
# <span class="w">  </span><span class="cm">/* initialize a, b */</span>
# <span class="w">  </span><span class="k">if</span><span class="p">(</span><span class="n">argc</span><span class="w"> </span><span class="o">&gt;=</span><span class="w"> </span><span class="mi">2</span><span class="p">)</span>
# <span class="w">    </span><span class="n">ARRAY_SIZE</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="n">atoi</span><span class="p">(</span><span class="n">argv</span><span class="p">[</span><span class="mi">1</span><span class="p">]);</span>
# <span class="w">  </span><span class="n">a</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="o">**</span><span class="p">)</span><span class="n">malloc</span><span class="p">(</span><span class="n">ARRAY_SIZE</span><span class="o">*</span><span class="k">sizeof</span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="o">*</span><span class="p">));</span>
# <span class="w">  </span><span class="k">for</span><span class="p">(</span><span class="n">i</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">;</span><span class="w"> </span><span class="n">i</span><span class="w"> </span><span class="o">&lt;</span><span class="w"> </span><span class="n">ARRAY_SIZE</span><span class="p">;</

# %%
! cd programmer; make clean; make madd_A madd_B
! echo "program,IC,Cycles,CPI,Freq(MHz),CT,ET" > madd.csv
! echo "running version A"; perf stat ./programmer/madd_A
! echo "running version B"; perf stat ./programmer/madd_B
# Out:
# rm -f madd_A madd_B madd_change_freq madd_A_O1 madd_B_O1 madd_A_O2 madd_B_O2 madd_A_O3 madd_B_O3 madd_A_O4 madd_B_O4 *~
# #hotspot hotspot_omp
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_A.c -o madd_A
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_B.c -o madd_B
# running version A
# 161
#
#  Performance counter stats for './programmer/madd_A':
#
#           1,751.93 msec task-clock                       #    0.997 CPUs utilized
#                 19      context-switches                 #   10.845 /sec
#                  2      cpu-migrations                   #    1.142 /sec
#            196,817      page-faults                      #  112.343 K/sec
#      6,841,889,733      cpu_atom/cycles/                 #    3.905 GHz                         (0.01%)
#      9,084,453,199      cpu_core/cycles/                 #    5.185 GHz                         (99.07%)
#      5,137,198,311      cpu_atom/instructions/           #    0.75  insn per cycle              (0.01%)
#     16,038,111,319      cpu_core/instructions/           #    1.77  insn per cycle              (99.07%)
#        947,424,926      cpu_atom/branches/               #  540.790 M/sec                       (0.01%)
#      2,511,059,637      cpu_core/branches/               #    1.433 G/sec                       (98.62%)
#         42,858,702      cpu_atom/branch-misses/          #    4.52% of all branches             (0.01%)
#          4,697,104      cpu_core/branch-misses/          #    0.19% of all branches             (98.62%)
#              TopdownL1 (cpu_core)                 #     63.3 %  tma_backend_bound
#                                                   #      1.2 %  tma_bad_speculation
#                                                   #      3.9 %  tma_frontend_bound
#                                                   #     31.6 %  tma_retiring             (99.07%)
#              TopdownL1 (cpu_atom)                 #     15.7 %  tma_bad_speculation
#                                                   #     19.6 %  tma_retiring             (0.01%)
#                                                   #     28.5 %  tma_backend_bound
#                                                   #     36.3 %  tma_frontend_bound       (0.01%)
#
#        1.756491599 seconds time elapsed
#
#        1.565739000 seconds user
#        0.186849000 seconds sys
#
#
# running version B
# 161
#
#  Performance counter stats for './programmer/madd_B':
#
#           2,227.91 msec task-clock                       #    0.998 CPUs utilized
#                 24      context-switches                 #   10.772 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#            196,818      page-faults                      #   88.342 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#     11,537,766,107      cpu_core/cycles/                 #    5.179 GHz                         (95.69%)
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#     16,601,180,074      cpu_core/instructions/           #    1.44  insn per cycle              (95.69%)
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#      2,645,423,696      cpu_core/branches/               #    1.187 G/sec                       (93.54%)
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#          5,030,415      cpu_core/branch-misses/          #    0.19% of all branches             (93.54%)
#              TopdownL1 (cpu_core)                 #     63.4 %  tma_backend_bound
#                                                   #      1.2 %  tma_bad_speculation
#                                                   #      3.5 %  tma_frontend_bound
#                                                   #     31.9 %  tma_retiring             (95.69%)
#
#        2.231813151 seconds time elapsed
#
#        2.048366000 seconds user
#        0.179944000 seconds sys

# %%
display_df_mono(render_csv("madd.csv"))
# Out:
# <style type="text/css">
# #T_88906_row0_col0, #T_88906_row0_col1, #T_88906_row0_col2, #T_88906_row0_col3, #T_88906_row0_col4, #T_88906_row0_col5, #T_88906_row0_col6, #T_88906_row0_col7, #T_88906_row1_col0, #T_88906_row1_col1, #T_88906_row1_col2, #T_88906_row1_col3, #T_88906_row1_col4, #T_88906_row1_col5, #T_88906_row1_col6, #T_88906_row1_col7 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_88906">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88906_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_88906_level0_col1" class="col_heading level0 col1" >program</th>
#       <th id="T_88906_level0_col2" class="col_heading level0 col2" >IC</th>
#       <th id="T_88906_level0_col3" class="col_heading level0 col3" >Cycles</th>
#       <th id="T_88906_level0_col4" class="col_heading level0 col4" >CPI</th>
#       <th id="T_88906_level0_col5" class="col_heading level0 col5" >Freq(MHz)</th>
#       <th id="T_88906_level0_col6" class="col_heading level0 col6" >CT</th>
#       <th id="T_88906_level0_col7" class="col_heading level0 col7" >ET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88906_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88906_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_88906_row0_col1" class="data row0 col1" >./programmer/madd_A</td>
#       <td id="T_88906_row0_col2" class="data row0 col2" >2144995962</td>
#       <td id="T_88906_row0_col3" class="data row0 col3" >393868911</td>
#       <td id="T_88906_row0_col4" class="data row0 col4" >0.183622</td>
#       <td id="T_88906_row0_col5" class="data row0 col5" >4282.906288</td>
#       <td id="T_88906_row0_col6" class="data row0 col6" >0.233486</td>
#       <td id="T_88906_row0_col7" class="data row0 col7" >0.091963</td>
#     </tr>
#     <tr>
#       <th id="T_88906_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88906_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_88906_row1_col1" class="data row1 col1" >./programmer/madd_B</td>
#       <td id="T_88906_row1_col2" class="data row1 col2" >2131251603</td>
#       <td id="T_88906_row1_col3" class="data row1 col3" >2459337531</td>
#       <td id="T_88906_row1_col4" class="data row1 col4" >1.153940</td>
#       <td id="T_88906_row1_col5" class="data row1 col5" >4291.655596</td>
#       <td id="T_88906_row1_col6" class="data row1 col6" >0.233010</td>
#       <td id="T_88906_row1_col7" class="data row1 col7" >0.573051</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare([do_render_code("../intro/arraySort.cpp",lang="c++", show="main"),do_render_code("../intro/calculate_sum.c",lang="c++", show="calculate_sum")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// ../intro/arraySort.cpp:1-37 (37 lines)</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;algorithm&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;ctime&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;iostream&gt;</span>
# <span class="cp">#include</span><span class="w"> </span><span class="cpf">&lt;climits&gt;</span>
#
# <span class="cp">#ifdef __cplusplus</span>
# <span class="k">extern</span><span class="w"> </span><span class="s">&quot;C&quot;</span><span class="w"> </span><span class="p">{</span>
# <span class="cp">#endif</span>
# <span class="kt">long</span><span class="w"> </span><span class="kt">long</span><span class="w"> </span><span class="nf">calculate_sum</span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="o">*</span><span class="n">data</span><span class="p">,</span><span class="w"> </span><span class="kt">unsigned</span><span class="w"> </span><span class="kt">int</span><span class="w"> </span><span class="n">size</span><span class="p">,</span><span class="w"> </span><span class="kt">int</span><span class="w"> </span><span class="n">threshold</span><span class="p">);</span>
# <span class="cp">#ifdef __cplusplus</span>
# <span class="p">}</span>
# <span class="cp">#endif</span>
#
#
# <span class="kt">int</span><span class="w"> </span><span class="n">main</span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="n">argc</span><span class="p">,</span><span class="w"> </span><span class="kt">char</span><span class="w"> </span><span class="o">**</span><span class="n">argv</span><span class="p">)</span>
# <span class="p">{</span>
# <span class="w">    </span><span class="c1">// generate data</span>
# <span class="c1">//    const unsigned arraySize = 262144;</span>
# <span class="w">    </span><span class="kt">int</span><span class="w"> </span><span class="n">arraySize</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="n">atoi</span><span class="p">(</span><span class="n">argv</span><span class="p">[</span><span class="mi">1</span><span class="p">]);</span>
# <span class="w">    </span><span class="kt">int</span><span class="w"> </span><span class="n">data</span><span class="p">[</span><span class="n">arraySize</span><span class="p">];</span>
# <span class="w">    </span><span class="kt">long</span><span class="w"> </span><span

# %%
! cd ../intro/; make clean; make; echo "not sorting"; perf stat ./arraySort 262144 1000 0; echo "sorting"; perf stat  ./arraySort 262144 1000 1
# Out:
# rm -f madd_A madd_B arraySort bitonic quicksort quicksort_cpu
# gcc -O3 madd_A.c -o madd_A
# gcc -O3 madd_B.c -o madd_B
# gcc calculate_sum.c -c
# g++ -O0 arraySort.cpp calculate_sum.o -o arraySort
# /usr/local/cuda/bin/nvcc -O3 bitonic.cu -o bitonic
# /usr/local/cuda/bin/nvcc -O3 quicksort.cu -o quicksort
# make: *** No rule to make target 'quicksort_cpu.cpp', needed by 'quicksort_cpu'.  Stop.
# not sorting
# sum = 127161197
#
#  Performance counter stats for './arraySort 262144 1000 0':
#
#             580.91 msec task-clock                       #    0.999 CPUs utilized
#                  9      context-switches                 #   15.493 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#                380      page-faults                      #  654.150 /sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#      3,010,976,265      cpu_core/cycles/                 #    5.183 GHz
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#      3,040,833,842      cpu_core/instructions/           #    1.01  insn per cycle
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#        530,686,805      cpu_core/branches/               #  913.550 M/sec
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#         67,965,173      cpu_core/branch-misses/          #   12.81% of all branches
#              TopdownL1 (cpu_core)                 #     11.5 %  tma_backend_bound
#                                                   #     46.3 %  tma_bad_speculation
#                                                   #     26.5 %  tma_frontend_bound
#                                                   #     15.7 %  tma_retiring
#
#        0.581588326 seconds time elapsed
#
#        0.580178000 seconds user
#        0.001000000 seconds sys
#
#
# sorting
# sum = 127161197
#
#  Performance counter stats for './arraySort 262144 1000 1':
#
#             164.82 msec task-clock                       #    0.996 CPUs utilized
#                  2      context-switches                 #   12.135 /sec
#                  1      cpu-migrations                   #    6.067 /sec
#                381      page-faults                      #    2.312 K/sec
#        571,874,450      cpu_atom/cycles/                 #    3.470 GHz                         (0.03%)
#        854,232,950      cpu_core/cycles/                 #    5.183 GHz                         (99.96%)
#        471,080,892      cpu_atom/instructions/           #    0.82  insn per cycle              (0.04%)
#      3,266,022,230      cpu_core/instructions/           #    3.82  insn per cycle              (99.96%)
#         86,467,042      cpu_atom/branches/               #  524.620 M/sec                       (0.04%)
#        564,612,765      cpu_core/branches/               #    3.426 G/sec                       (99.96%)
#          2,627,914      cpu_atom/branch-misses/          #    3.04% of all branches             (0.04%)
#          1,966,602      cpu_core/branch-misses/          #    0.35% of all branches             (99.96%)
#              TopdownL1 (cpu_core)                 #     28.1 %  tma_backend_bound
#                                                   #      5.5 %  tma_bad_speculation
#                                                   #      5.0 %  tma_frontend_bound
#                                                   #     61.3 %  tma_retiring             (99.96%)
#              TopdownL1 (cpu_atom)                 #     44.0 %  tma_bad_speculation
#                                                   #     19.9 %  tma_retiring             (0.04%)
#                                                   #      8.6 %  tma_backend_bound
#                                                   #     27.5 %  tma_frontend_bound       (0.04%)
#
#        0.165483585 seconds time elapsed
#
#        0.164210000 seconds user
#        0.001001000 seconds sys

# %% [markdown]
# ### Perl

# %%
render_code("./programming_languages/hello.pl")
# Out:
# // ./programming_languages/hello.pl:1-5 (5 lines)
# #!/usr/bin/perl
# use strict;
# use warnings;
#
# print "Hello, World!\n";

# %%
! perf stat ./programming_languages/hello.pl
# Out:
# Hello, World!
#
#  Performance counter stats for './programming_languages/hello.pl':
#
#               1.90 msec task-clock                       #    0.801 CPUs utilized
#                  1      context-switches                 #  526.802 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#                309      page-faults                      #  162.782 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#          9,656,558      cpu_core/cycles/                 #    5.087 GHz
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#         14,737,455      cpu_core/instructions/           #    1.53  insn per cycle
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#          2,995,290      cpu_core/branches/               #    1.578 G/sec
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#             68,522      cpu_core/branch-misses/          #    2.29% of all branches
#              TopdownL1 (cpu_core)                 #     22.3 %  tma_backend_bound
#                                                   #     11.9 %  tma_bad_speculation
#                                                   #     41.2 %  tma_frontend_bound
#                                                   #     24.6 %  tma_retiring
#
#        0.002370592 seconds time elapsed
#
#        0.001447000 seconds user
#        0.000723000 seconds sys

# %% [markdown]
# ### Java

# %%
render_code("./programming_languages/HelloWorld.java")
# Out:
# // ./programming_languages/HelloWorld.java:1-8 (8 lines)
# public class HelloWorld {
#
#     public static void main(String[] args) {
#         // Prints "Hello, World" to the terminal window.
#         System.out.println("Hello, World");
#     }
#
# }

# %%
! cd ./programming_languages/; javac HelloWorld.java
! cd ./programming_languages/; perf stat java HelloWorld
# Out:
# Hello, World
#
#  Performance counter stats for 'java HelloWorld':
#
#              32.70 msec task-clock                       #    0.948 CPUs utilized
#                102      context-switches                 #    3.119 K/sec
#                 15      cpu-migrations                   #  458.687 /sec
#              6,173      page-faults                      #  188.765 K/sec
#        130,055,656      cpu_atom/cycles/                 #    3.977 GHz                         (66.72%)
#        138,777,563      cpu_core/cycles/                 #    4.244 GHz                         (5.69%)
#        114,039,182      cpu_atom/instructions/           #    0.88  insn per cycle              (76.02%)
#        257,887,758      cpu_core/instructions/           #    1.86  insn per cycle              (5.69%)
#         20,291,014      cpu_atom/branches/               #  620.481 M/sec                       (82.25%)
#         42,585,295      cpu_core/branches/               #    1.302 G/sec                       (5.69%)
#            541,504      cpu_atom/branch-misses/          #    2.67% of all branches             (79.36%)
#            300,177      cpu_core/branch-misses/          #    0.70% of all branches             (5.69%)
#              TopdownL1 (cpu_core)                 #     46.5 %  tma_backend_bound
#                                                   #      4.6 %  tma_bad_speculation
#                                                   #     18.3 %  tma_frontend_bound
#                                                   #     30.6 %  tma_retiring             (5.69%)
#              TopdownL1 (cpu_atom)                 #     13.7 %  tma_bad_speculation
#                                                   #     21.1 %  tma_retiring             (82.85%)
#                                                   #     38.3 %  tma_backend_bound
#                                                   #     26.9 %  tma_frontend_bound       (87.53%)
#
#        0.034485737 seconds time elapsed
#
#        0.014932000 seconds user
#        0.019199000 seconds sys

# %% [markdown]
# ### Go

# %%
render_code("./programming_languages/hello-world.go")
# Out:
# // ./programming_languages/hello-world.go:1-5 (5 lines)
# package main
# import "fmt"
# func main() {
#     fmt.Println("hello world")
# }

# %%
! perf stat /usr/local/go/bin/go run ./programming_languages/hello-world.go
# Out:
# hello world
#
#  Performance counter stats for '/usr/local/go/bin/go run ./programming_languages/hello-world.go':
#
#             170.11 msec task-clock                       #    1.591 CPUs utilized
#              3,559      context-switches                 #   20.922 K/sec
#                986      cpu-migrations                   #    5.796 K/sec
#             22,283      page-faults                      #  130.993 K/sec
#        643,659,944      cpu_atom/cycles/                 #    3.784 GHz                         (22.48%)
#        769,457,526      cpu_core/cycles/                 #    4.523 GHz                         (58.22%)
#        641,943,767      cpu_atom/instructions/           #    1.00  insn per cycle              (32.74%)
#      1,068,161,528      cpu_core/instructions/           #    1.39  insn per cycle              (58.22%)
#        119,953,826      cpu_atom/branches/               #  705.162 M/sec                       (35.88%)
#        207,307,682      cpu_core/branches/               #    1.219 G/sec                       (58.22%)
#          2,988,334      cpu_atom/branch-misses/          #    2.49% of all branches             (37.38%)
#          3,494,525      cpu_core/branch-misses/          #    1.69% of all branches             (58.22%)
#              TopdownL1 (cpu_core)                 #     30.2 %  tma_backend_bound
#                                                   #     13.0 %  tma_bad_speculation
#                                                   #     29.7 %  tma_frontend_bound
#                                                   #     27.0 %  tma_retiring             (58.22%)
#              TopdownL1 (cpu_atom)                 #     13.5 %  tma_bad_speculation
#                                                   #     24.0 %  tma_retiring             (36.92%)
#                                                   #     34.3 %  tma_backend_bound
#                                                   #     28.2 %  tma_frontend_bound       (37.94%)
#
#        0.106939016 seconds time elapsed
#
#        0.083460000 seconds user
#        0.090688000 seconds sys

# %%
# !/usr/local/go/bin/go build ./programming_languages/hello-world.go
! perf stat ./hello-world
# Out:
# hello world
#
#  Performance counter stats for './hello-world':
#
#               1.68 msec task-clock                       #    0.152 CPUs utilized
#                 49      context-switches                 #   29.187 K/sec
#                  4      cpu-migrations                   #    2.383 K/sec
#                247      page-faults                      #  147.126 K/sec
#          6,472,749      cpu_atom/cycles/                 #    3.856 GHz                         (41.85%)
#          5,854,616      cpu_core/cycles/                 #    3.487 GHz                         (6.01%)
#          4,491,920      cpu_atom/instructions/           #    0.69  insn per cycle              (93.99%)
#          4,116,725      cpu_core/instructions/           #    0.70  insn per cycle              (6.01%)
#            789,501      cpu_atom/branches/               #  470.269 M/sec                       (93.99%)
#            706,349      cpu_core/branches/               #  420.739 M/sec                       (6.01%)
#             23,302      cpu_atom/branch-misses/          #    2.95% of all branches             (93.99%)
#             14,169      cpu_core/branch-misses/          #    2.01% of all branches             (6.01%)
#              TopdownL1 (cpu_core)                 #     63.7 %  tma_backend_bound
#                                                   #      5.1 %  tma_bad_speculation
#                                                   #     19.1 %  tma_frontend_bound
#                                                   #     12.1 %  tma_retiring             (6.01%)
#              TopdownL1 (cpu_atom)                 #     20.8 %  tma_bad_speculation
#                                                   #     20.2 %  tma_retiring             (93.99%)
#                                                   #     29.9 %  tma_backend_bound
#                                                   #     29.1 %  tma_frontend_bound       (93.99%)
#
#        0.011029316 seconds time elapsed
#
#        0.000600000 seconds user
#        0.001802000 seconds sys

# %% [markdown]
# ### C++

# %%
render_code("./programming_languages/hello.cpp")
# Out:
# // ./programming_languages/hello.cpp:1-8 (8 lines)
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     cout << "Hello, World!";
#     return 0;
# }

# %%
! g++ -O4 ./programming_languages/hello.cpp -o ./programming_languages/hello_cpp
! perf stat ./programming_languages/hello_cpp
# Out:
# Hello, World!
#  Performance counter stats for './programming_languages/hello_cpp':
#
#               0.84 msec task-clock                       #    0.402 CPUs utilized
#                  0      context-switches                 #    0.000 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#                125      page-faults                      #  148.406 K/sec
#          3,370,293      cpu_atom/cycles/                 #    4.001 GHz                         (40.98%)
#      <not counted>      cpu_core/cycles/                                                        (0.00%)
#          3,837,804      cpu_atom/instructions/           #    1.14  insn per cycle
#      <not counted>      cpu_core/instructions/                                                  (0.00%)
#            677,161      cpu_atom/branches/               #  803.956 M/sec
#      <not counted>      cpu_core/branches/                                                      (0.00%)
#             17,698      cpu_atom/branch-misses/          #    2.61% of all branches
#      <not counted>      cpu_core/branch-misses/                                                 (0.00%)
#              TopdownL1 (cpu_atom)                 #     16.6 %  tma_bad_speculation
#                                                   #     26.2 %  tma_retiring
#                                                   #     33.8 %  tma_backend_bound
#                                                   #     23.4 %  tma_frontend_bound
#
#        0.002092761 seconds time elapsed
#
#        0.000000000 seconds user
#        0.001261000 seconds sys

# %% [markdown]
# ### C

# %%
render_code("./programming_languages/hello.c")
# Out:
# // ./programming_languages/hello.c:1-7 (7 lines)
# #include <stdio.h>
#
# int main()
# {
#     printf("Hello, world!\n");
#     return 0;
# }

# %%
! gcc -O4 ./programming_languages/hello.c -o ./programming_languages/hello_c
! perf stat ./programming_languages/hello_c
# Out:
# Hello, world!
#
#  Performance counter stats for './programming_languages/hello_c':
#
#               0.30 msec task-clock                       #    0.220 CPUs utilized
#                  0      context-switches                 #    0.000 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#                 57      page-faults                      #  190.062 K/sec
#          1,198,822      cpu_atom/cycles/                 #    3.997 GHz
#      <not counted>      cpu_core/cycles/                                                        (0.00%)
#          1,172,844      cpu_atom/instructions/           #    0.98  insn per cycle
#      <not counted>      cpu_core/instructions/                                                  (0.00%)
#            211,267      cpu_atom/branches/               #  704.453 M/sec
#      <not counted>      cpu_core/branches/                                                      (0.00%)
#              7,520      cpu_atom/branch-misses/          #    3.56% of all branches
#      <not counted>      cpu_core/branch-misses/                                                 (0.00%)
#              TopdownL1 (cpu_atom)                 #     42.3 %  tma_bad_speculation
#                                                   #     24.2 %  tma_retiring
#                                                   #      0.0 %  tma_backend_bound
#                                                   #     33.5 %  tma_frontend_bound
#
#        0.001365042 seconds time elapsed
#
#        0.000533000 seconds user
#        0.000000000 seconds sys

# %%
! make -C programmer clean; make -C programmer madd_A; rm madd.csv
! echo "program,IC,Cycles,CPI,Freq(MHz),CT,ET" > madd.csv
! echo "running version A (Unoptimized)"
! perf stat ./programmer/madd_A
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# rm -f madd_A madd_B madd_change_freq madd_A_O1 madd_B_O1 madd_A_O2 madd_B_O2 madd_A_O3 madd_B_O3 madd_A_O4 madd_B_O4 *~
# #hotspot hotspot_omp
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_A.c -o madd_A
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# running version A (Unoptimized)
# 161
#
#  Performance counter stats for './programmer/madd_A':
#
#           1,768.35 msec task-clock                       #    0.998 CPUs utilized
#                 20      context-switches                 #   11.310 /sec
#                  3      cpu-migrations                   #    1.696 /sec
#            196,818      page-faults                      #  111.300 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#      9,143,538,277      cpu_core/cycles/                 #    5.171 GHz                         (99.10%)
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#     16,058,544,851      cpu_core/instructions/           #    1.76  insn per cycle              (99.10%)
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#      2,512,106,486      cpu_core/branches/               #    1.421 G/sec                       (98.64%)
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#          4,601,778      cpu_core/branch-misses/          #    0.18% of all branches             (98.64%)
#              TopdownL1 (cpu_core)                 #     63.4 %  tma_backend_bound
#                                                   #      1.2 %  tma_bad_speculation
#                                                   #      3.5 %  tma_frontend_bound
#                                                   #     31.9 %  tma_retiring             (99.10%)
#
#        1.771320774 seconds time elapsed
#
#        1.617944000 seconds user
#        0.150901000 seconds sys

# %%
! cd programmer; make clean; make madd_B
! echo "running version B (Unoptimized)"; time ./programmer/madd_B
# Out:
# rm -f madd_A madd_B madd_change_freq madd_A_O1 madd_B_O1 madd_A_O2 madd_B_O2 madd_A_O3 madd_B_O3 madd_A_O4 madd_B_O4 *~
# #hotspot hotspot_omp
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_B.c -o madd_B
# running version B (Unoptimized)
# 161
#
# real	0m2.171s
# user	0m2.007s
# sys	0m0.149s

# %%
! cd programmer;make madd_A_O1; make madd_A_O2; make madd_A_O3; make madd_A_O4
#! echo "running version A (Optimized)"
#! perf stat ./programmer/madd_A_O4
# !./programmer/madd_A_O1; ./programmer/madd_A_O2; ./programmer/madd_A_O3; ./programmer/madd_A_O4
# Out:
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O1 perfstats.o madd_A.c -o madd_A_O1
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O2 perfstats.o madd_A.c -o madd_A_O2
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3 perfstats.o madd_A.c -o madd_A_O3
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O4 perfstats.o madd_A.c -o madd_A_O4
# 161
# 161
# 161
# 161

# %%
#! cd programmer; make madd_B_O3
#! echo "running version B (Optimized)"; time ./programmer/madd_B_O3
! cd programmer;make madd_B_O1; make madd_B_O2; make madd_B_O3; make madd_B_O4
# !./programmer/madd_B_O1; ./programmer/madd_B_O2; ./programmer/madd_B_O3; ./programmer/madd_B_O4
# Out:
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O1 perfstats.o madd_B.c -o madd_B_O1
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O2 perfstats.o madd_B.c -o madd_B_O2
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3 perfstats.o madd_B.c -o madd_B_O3
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O4 perfstats.o madd_B.c -o madd_B_O4
# 161
# 161
# 161
# 161

# %%
display_df_mono(render_csv("madd.csv"))
# Out:
# <style type="text/css">
# #T_b6dce_row0_col0, #T_b6dce_row0_col1, #T_b6dce_row0_col2, #T_b6dce_row0_col3, #T_b6dce_row0_col4, #T_b6dce_row0_col5, #T_b6dce_row0_col6, #T_b6dce_row1_col0, #T_b6dce_row1_col1, #T_b6dce_row1_col2, #T_b6dce_row1_col3, #T_b6dce_row1_col4, #T_b6dce_row1_col5, #T_b6dce_row1_col6, #T_b6dce_row2_col0, #T_b6dce_row2_col1, #T_b6dce_row2_col2, #T_b6dce_row2_col3, #T_b6dce_row2_col4, #T_b6dce_row2_col5, #T_b6dce_row2_col6, #T_b6dce_row3_col0, #T_b6dce_row3_col1, #T_b6dce_row3_col2, #T_b6dce_row3_col3, #T_b6dce_row3_col4, #T_b6dce_row3_col5, #T_b6dce_row3_col6, #T_b6dce_row4_col0, #T_b6dce_row4_col1, #T_b6dce_row4_col2, #T_b6dce_row4_col3, #T_b6dce_row4_col4, #T_b6dce_row4_col5, #T_b6dce_row4_col6, #T_b6dce_row5_col0, #T_b6dce_row5_col1, #T_b6dce_row5_col2, #T_b6dce_row5_col3, #T_b6dce_row5_col4, #T_b6dce_row5_col5, #T_b6dce_row5_col6, #T_b6dce_row6_col0, #T_b6dce_row6_col1, #T_b6dce_row6_col2, #T_b6dce_row6_col3, #T_b6dce_row6_col4, #T_b6dce_row6_col5, #T_b6dce_row6_col6, #T_b6dce_row7_col0, #T_b6dce_row7_col1, #T_b6dce_row7_col2, #T_b6dce_row7_col3, #T_b6dce_row7_col4, #T_b6dce_row7_col5, #T_b6dce_row7_col6, #T_b6dce_row8_col0, #T_b6dce_row8_col1, #T_b6dce_row8_col2, #T_b6dce_row8_col3, #T_b6dce_row8_col4, #T_b6dce_row8_col5, #T_b6dce_row8_col6, #T_b6dce_row9_col0, #T_b6dce_row9_col1, #T_b6dce_row9_col2, #T_b6dce_row9_col3, #T_b6dce_row9_col4, #T_b6dce_row9_col5, #T_b6dce_row9_col6 {
#   background-color: grey;
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_b6dce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6dce_level0_col0" class="col_heading level0 col0" >program</th>
#       <th id="T_b6dce_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_b6dce_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_b6dce_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_b6dce_level0_col4" class="col_heading level0 col4" >Freq(MHz)</th>
#       <th id="T_b6dce_level0_col5" class="col_heading level0 col5" >CT</th>
#       <th id="T_b6dce_level0_col6" class="col_heading level0 col6" >ET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6dce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6dce_row0_col0" class="data row0 col0" >./programmer/madd_A</td>
#       <td id="T_b6dce_row0_col1" class="data row0 col1" >2127403196</td>
#       <td id="T_b6dce_row0_col2" class="data row0 col2" >408643341</td>
#       <td id="T_b6dce_row0_col3" class="data row0 col3" >0.192086</td>
#       <td id="T_b6dce_row0_col4" class="data row0 col4" >4247.984251</td>
#       <td id="T_b6dce_row0_col5" class="data row0 col5" >0.235406</td>
#       <td id="T_b6dce_row0_col6" class="data row0 col6" >0.096197</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6dce_row1_col0" class="data row1 col0" >./programmer/madd_B</td>
#       <td id="T_b6dce_row1_col1" class="data row1 col1" >2556578719</td>
#       <td id="T_b6dce_row1_col2" class="data row1 col2" >2954668653</td>
#       <td id="T_b6dce_row1_col3" class="data row1 col3" >1.155712</td>
#       <td id="T_b6dce_row1_col4" class="data row1 col4" >5184.293169</td>
#       <td id="T_b6dce_row1_col5" class="data row1 col5" >0.192890</td>
#       <td id="T_b6dce_row1_col6" class="data row1 col6" >0.569927</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6dce_row2_col0" class="data row2 col0" >./programmer/madd_A_O1</td>
#       <td id="T_b6dce_row2_col1" class="data row2 col1" >403099280</td>
#       <td id="T_b6dce_row2_col2" class="data row2 col2" >164167559</td>
#       <td id="T_b6dce_row2_col3" class="data row2 col3" >0.407263</td>
#       <td id="T_b6dce_row2_col4" class="data row2 col4" >5187.460391</td>
#       <td id="T_b6dce_row2_col5" class="data row2 col5" >0.192773</td>
#       <td id="T_b6dce_row2_col6" class="data row2 col6" >0.031647</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6dce_row3_col0" class="data row3 col0" >./programmer/madd_A_O2</td>
#       <td id="T_b6dce_row3_col1" class="data row3 col1" >403096671</td>
#       <td id="T_b6dce_row3_col2" class="data row3 col2" >164919283</td>
#       <td id="T_b6dce_row3_col3" class="data row3 col3" >0.409131</td>
#       <td id="T_b6dce_row3_col4" class="data row3 col4" >5184.999623</td>
#       <td id="T_b6dce_row3_col5" class="data row3 col5" >0.192864</td>
#       <td id="T_b6dce_row3_col6" class="data row3 col6" >0.031807</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6dce_row4_col0" class="data row4 col0" >./programmer/madd_A_O3</td>
#       <td id="T_b6dce_row4_col1" class="data row4 col1" >117867511</td>
#       <td id="T_b6dce_row4_col2" class="data row4 col2" >142151578</td>
#       <td id="T_b6dce_row4_col3" class="data row4 col3" >1.206029</td>
#       <td id="T_b6dce_row4_col4" class="data row4 col4" >5191.234635</td>
#       <td id="T_b6dce_row4_col5" class="data row4 col5" >0.192632</td>
#       <td id="T_b6dce_row4_col6" class="data row4 col6" >0.027383</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6dce_row5_col0" class="data row5 col0" >./programmer/madd_A_O4</td>
#       <td id="T_b6dce_row5_col1" class="data row5 col1" >117884711</td>
#       <td id="T_b6dce_row5_col2" class="data row5 col2" >139478745</td>
#       <td id="T_b6dce_row5_col3" class="data row5 col3" >1.183179</td>
#       <td id="T_b6dce_row5_col4" class="data row5 col4" >5186.047407</td>
#       <td id="T_b6dce_row5_col5" class="data row5 col5" >0.192825</td>
#       <td id="T_b6dce_row5_col6" class="data row5 col6" >0.026895</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6dce_row6_col0" class="data row6 col0" >./programmer/madd_B_O1</td>
#       <td id="T_b6dce_row6_col1" class="data row6 col1" >611589638</td>
#       <td id="T_b6dce_row6_col2" class="data row6 col2" >3504243303</td>
#       <td id="T_b6dce_row6_col3" class="data row6 col3" >5.729730</td>
#       <td id="T_b6dce_row6_col4" class="data row6 col4" >5177.932226</td>
#       <td id="T_b6dce_row6_col5" class="data row6 col5" >0.193127</td>
#       <td id="T_b6dce_row6_col6" class="data row6 col6" >0.676765</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6dce_row7_col0" class="data row7 col0" >./programmer/madd_B_O2</td>
#       <td id="T_b6dce_row7_col1" class="data row7 col1" >611362046</td>
#       <td id="T_b6dce_row7_col2" class="data row7 col2" >3451116334</td>
#       <td id="T_b6dce_row7_col3" class="data row7 col3" >5.644963</td>
#       <td id="T_b6dce_row7_col4" class="data row7 col4" >5182.229851</td>
#       <td id="T_b6dce_row7_col5" class="data row7 col5" >0.192967</td>
#       <td id="T_b6dce_row7_col6" class="data row7 col6" >0.665952</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b6dce_row8_col0" class="data row8 col0" >./programmer/madd_B_O3</td>
#       <td id="T_b6dce_row8_col1" class="data row8 col1" >611356471</td>
#       <td id="T_b6dce_row8_col2" class="data row8 col2" >3441617821</td>
#       <td id="T_b6dce_row8_col3" class="data row8 col3" >5.629478</td>
#       <td id="T_b6dce_row8_col4" class="data row8 col4" >5185.111595</td>
#       <td id="T_b6dce_row8_col5" class="data row8 col5" >0.192860</td>
#       <td id="T_b6dce_row8_col6" class="data row8 col6" >0.663750</td>
#     </tr>
#     <tr>
#       <th id="T_b6dce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b6dce_row9_col0" class="data row9 col0" >./programmer/madd_B_O4</td>
#       <td id="T_b6dce_row9_col1" class="data row9 col1" >611250180</td>
#       <td id="T_b6dce_row9_col2" class="data row9 col2" >3428493700</td>
#       <td id="T_b6dce_row9

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Question:
#
# What's the limitation of compiler?
#
# </div>
