# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# # Our processor

# %% [markdown]
# # Choose the "right" metrics
#
# ## Throughput and Latency
#
# ### SSD v.s. HDD
#
# You may use to hdparm (need root permission to execute). The /dev/sda on this machine is an SATA SSD that has around 450-500MB/sec bandwidth. The /dev/md0 is a RAID contains two H.D.Ds in RAID-0 configuration that also achieves 450-500MB/sec bandwidth. Let's examine the bandwidth using the following command.

# %%
from IPython.display import IFrame
IFrame("https://hub.escalab.org/user/htseng/terminals/1", width="100%", height="400")

# %%
! cp ../300000000.bin /tmp/300000000.bin
! echo "Configuration,Size,ET,FileInput,CPU_Kernel,GPU_Kernel,Host2GPU,GPU2Host" > sort_small.csv
! echo "File on H.D.D"
! cd gpusort; source ./run_small 512 2>> ../sort_small.csv
! echo "File on S.S.D"
! cd gpusort; source ./run_small_SSD 512 2>> ../sort_small.csv
! echo "File on H.D.D"
! cd gpusort; source ./run_small 32768 2>> ../sort_small.csv
! echo "File on S.S.D"
! cd gpusort; source ./run_small_SSD 32768 2>> ../sort_small.csv
! echo "File on H.D.D"
! cd gpusort; source ./run_small 262144 2>> ../sort_small.csv
! echo "File on S.S.D"
! cd gpusort; source ./run_small_SSD 262144 2>> ../sort_small.csv
! rm -f /tmp/300000000.bin
display_df_mono((render_csv("sort_small.csv")))
# Out:
# File on H.D.D
# Sorting list of 512 floats
# FileInput 0.000080 seconds
# Sorting on GPU...GPU iterations: 1
# Total GPU Sort execution time: 0.000275 seconds
#     - Upload		: 0.000013 seconds
#     - Download		: 0.000008 seconds
# Sorting list of 512 floats
# FileInput 0.000164 seconds
# Sorting on CPU...done.
# Total CPU execution time: 0.000031 seconds
# File on S.S.D
# Sorting list of 512 floats
# FileInput 0.000032 seconds
# Sorting on GPU...GPU iterations: 1
# Total GPU Sort execution time: 0.000286 seconds
#     - Upload		: 0.000013 seconds
#     - Download		: 0.000008 seconds
# Sorting list of 512 floats
# FileInput 0.000029 seconds
# Sorting on CPU...done.
# Total CPU execution time: 0.000032 seconds
# File on H.D.D
# Sorting list of 32768 floats
# FileInput 0.000174 seconds
# Sorting on GPU...GPU iterations: 1
# Total GPU Sort execution time: 0.000448 seconds
#     - Upload		: 0.000025 seconds
#     - Download		: 0.000052 seconds
# Sorting list of 32768 floats
# FileInput 0.000158 seconds
# Sorting on CPU...done.
# Total CPU execution time: 0.003236 seconds
# File on S.S.D
# Sorting list of 32768 floats
# FileInput 0.000078 seconds
# Sorting on GPU...GPU iterations: 1
# Total GPU Sort execution time: 0.000433 seconds
#     - Upload		: 0.000021 seconds
#     - Download		: 0.000052 seconds
# Sorting list of 32768 floats
# FileInput 0.000109 seconds
# Sorting on CPU...done.
# Total CPU execution time: 0.003217 seconds
# File on H.D.D
# Sorting list of 262144 floats
# FileInput 0.000460 seconds
# Sorting on GPU...GPU iterations: 1
# Total GPU Sort execution time: 0.000799 seconds
#     - Upload		: 0.000084 seconds
#     - Download		: 0.000370 seconds
# Sorting list of 262144 floats
# FileInput 0.000552 seconds
# Sorting on CPU...done.
# Total CPU execution time: 0.023382 seconds
# File on S.S.D
# Sorting list of 262144 floats
# FileInput 0.000556 seconds
# Sorting on GPU...GPU iterations: 1
# Total GPU Sort execution time: 0.000711 seconds
#     - Upload		: 0.000088 seconds
#     - Download		: 0.000361 seconds
# Sorting list of 262144 floats
# FileInput 0.000594 seconds
# Sorting on CPU...done.
# Total CPU execution time: 0.020913 seconds
# <style type="text/css">
