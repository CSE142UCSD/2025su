# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
render_code("mv/matvec.c")
# Out:
# // mv/matvec.c:1-68 (68 lines)
# #include <stdio.h>
# #include <stdlib.h>
#
# int ARRAY_SIZE = 8192;
#
# int main(int argc, char **argv)
# {
#   double **a, *b, *c, result;
#   int i,j,dump=0,i_first=1;
#   /* initialize a, b */
#   if(argc >= 2)
#     ARRAY_SIZE = atoi(argv[1]);
#   if(argc >= 3)
#     dump = atoi(argv[2]);
#   if(argc >= 4)
#     i_first = atoi(argv[3]);
#   a = (double **)malloc(ARRAY_SIZE*sizeof(double *));
#   for(i = 0; i < ARRAY_SIZE; i++)
#   {
#     a[i] = (double *)malloc(ARRAY_SIZE*sizeof(double));
#     for(j = 0; j < ARRAY_SIZE; j++)
#       a[i][j] = (rand()%100)+1;
#   }
#
#   b = (double *)malloc(ARRAY_SIZE*sizeof(double));
#   for(i = 0; i < ARRAY_SIZE; i++)
#       b[i] = (rand()%100)+1;
#
#   c = (double *)malloc(ARRAY_SIZE*sizeof(double));
#
#   for(i = 0; i < ARRAY_SIZE; i++)
#       c[i] = 0.0;
#   /* Do matrix addition */
#     if(i_first)
#   //I_FIRST_START
#     for(i = 0; i < ARRAY_SIZE; i++)
#     {
#       result = 0.0;
# ...

# %%
! make -C mv clean all
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/mv'
# rm -f matvec
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3  matvec.c -o matvec
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/mv'

# %%
! ~/bin/sde64 -mix -omix foo.out -- mv/matvec 16 0
# Out:
# 28799.000000,22046
